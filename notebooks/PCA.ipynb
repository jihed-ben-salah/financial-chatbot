# %%
import pandas as pd

# %%
data=pd.read_csv('../dash-sample-apps/apps/dash-tsne/demo_embeddings/financial/iterations_250/perplexity_3/pca_25/learning_rate_10/data.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'x', 'y', 'z'], dtype='object')

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_3d(data, x='x', y='y', z='z', hover_data=['Unnamed: 0'])
fig.show()
